# %% [markdown]
# <a href="https://colab.research.google.com/github/maltabenassi/linguagem-programacao/blob/main/02_03_LP_se%C3%A7%C3%A3o_1_2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# --- PROJETO: DESAFIO DO NÚMERO SECRETO (SEÇÃO 1.2) ---
import random

# 1. Definição de Variáveis (Objetos no Python)
numero_secreto = random.randint(1, 20)
tentativas = 0
max_tentativas = 5
vitoria = False

print("="*40)
print("SISTEMA DE ADIVINHAÇÃO - LINGUAGEM PYTHON")
print("="*40)
print(f"Dica: Tente adivinhar o número entre 1 e 20 em {max_tentativas} chances.")

# 2. Estrutura de Repetição (while) - Conforme Figura 1.7 do livro
while tentativas < max_tentativas:
    # Captura e Conversão de Tipo (int + input)
    try:
        chute = int(input(f"\nTentativa {tentativas + 1} de {max_tentativas}. Digite seu número: "))
    except ValueError:
        print("Erro: Por favor, digite apenas números inteiros!")
        continue

    tentativas += 1

    # 3. Estruturas Condicionais Compostas e Encadeadas (if, elif, else)
    if chute == numero_secreto:
        print(f"Caminho VERDADEIRO: Você acertou! O número era {numero_secreto}.")
        vitoria = True
        break  # Comando de interrupção abordado no livro

    elif chute < numero_secreto:
        print("Resultado: FALSO. O número secreto é MAIOR que seu chute.")

    else:
        print("Resultado: FALSO. O número secreto é MENOR que seu chute.")

    # 4. Estrutura Lógica (and) - Verificando derrota
    if tentativas == max_tentativas and not vitoria:
        print(f"\n[GAME OVER] Você atingiu o limite de {max_tentativas} tentativas.")
        print(f"O número secreto era: {numero_secreto}")

print("\n" + "="*40)
print("Execução finalizada com base na Unidade 1.2")
# Out:
# ...
# SISTEMA DE ADIVINHAÇÃO - LINGUAGEM PYTHON
# ...
# Dica: Tente adivinhar o número entre 1 e 20 em 5 chances.
#
# Tentativa 1 de 5. Digite seu número: 15
# Resultado: FALSO. O número secreto é MENOR que seu chute.
#
# Tentativa 2 de 5. Digite seu número: 10
# Resultado: FALSO. O número secreto é MENOR que seu chute.
#
# Tentativa 3 de 5. Digite seu número: 5
# Resultado: FALSO. O número secreto é MAIOR que seu chute.
#
# Tentativa 4 de 5. Digite seu número: 8
# Resultado: FALSO. O número secreto é MAIOR que seu chute.
#
# Tentativa 5 de 5. Digite seu número: 9
# Caminho VERDADEIRO: Você acertou! O número era 9.
#
# ...
# Execução finalizada com base na Unidade 1.2

# %% [markdown]
# O Objetivo desse "Jogo" é demonstrar na pratica alguns dos conceitos basicos de programação referentes ao capitulo 1.2 do livro que abordam estruturas "condicionais e de repetição".
#
# Como por exemplo:
# while = Utilizada para criar um ciclo de execução que permanece ativo enquanto uma condição lógica for verdadeira (neste caso, enquanto o usuário tiver tentativas disponíveis e não tiver acertado o número).
#
# if,elif e else = Aplicadas para realizar a tomada de decisão do algoritmo. O programa compara o valor inserido pelo usuário com o valor armazenado, decidindo qual mensagem exibir (Maior, Menor ou Acerto).
#
# Operadores Relacionais e Lógicos = Uso de operadores como == (igualdade), < (menor que) e o operador lógico and para verificar múltiplas condições simultâneas (como o fim das tentativas e o status de vitória).
#
# Tipagem Dinâmica e Conversão: Demonstração da função input() para entrada de dados e a função int() para a conversão de string para inteiro, permitindo operações matemáticas e comparativas.
